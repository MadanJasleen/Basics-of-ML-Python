# %%
import pandas as pd
import numpy as py

# %%
import requests
from bs4 import BeautifulSoup

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage = requests.get('https://www.ambitionbox.com/list-of-companies?campaign=desktop_nav&page=1',headers = headers).text

# %%
soup = BeautifulSoup(webpage, 'html.parser')

# %%
#print(soup.prettify)

# %%
soup.find_all('h1')[0].text
# Out:
# '\n\t\t\t\t\t\t\tList of companies in India\n\t\t\t\t\t\t'

# %%
len(soup.find_all('h2'))
# Out:
# 24

# %%
for i in soup.find_all('h2') :
    print(i.text.strip())
# Out:
# TCS
# Accenture
# Cognizant
# Wipro
# Capgemini
# HDFC Bank
# ICICI Bank
# Infosys
# HCLTech
# Tech Mahindra
# Genpact
# Axis Bank
# Teleperformance
# Concentrix Corporation
# Jio
# Amazon
# IBM
# Reliance Retail
# HDB Financial Services
# Larsen & Toubro Limited
# Companies by  Industry
# Companies by  Locations
# Companies by  Type
# Companies by  Badges

# %%
 #issue is there are many span types 
for i in soup.find_all('span'):
       print(i.text.strip())
# Out:
# +
#
# Companies
# Reviews
# Salaries
# Interviews
# Awards
# Participate in ABECA 2025
# All Filters
#
#
#
#
#
#
#
#
# 9,86,353
# 							unique
# 							companies found
# Follow
# 3.8
# IT Services & Consulting | 1 Lakh+ Employees | Public | 56 years old | Mumbai +342 more
# Highly Rated For
# Job Security, Work Life Balance
# Critically Rated For
# Promotions / Appraisal, Salary & Benefits
# 73.8k
# Reviews
# 856.6k
# Salaries
# 6.4k
# Interviews
# 960
# Jobs
# 11.6k
# Benefits
# 77
# Photos
# Follow
# 4.0
# IT Services & Consulting | 1 Lakh+ Employees | Public | 35 years old | Dublin +175 more
# Highly Rated For
# Company Culture, Skill Development / Learning, Job Security
# 46.8k
# Reviews
# 586.6k
# Salaries
# 4.6k
# Interviews
# 22.5k
# Jobs
# 7.1k
# Benefits
# 39
# Photos
#
# Follow
# 3.9
# IT Services & Consulting | 1 Lakh+ Employees | Forbes Global 2000 | 30 years old | Teaneck. New Jersey. +159 more
# Highly Rated For
# Skill Development / Learning
# Critically Rated For
# ...

# %%
#specify class

for i in soup.find_all('span', class_= 'companyCardWrapper__companyRatingValue') :
    print(i.text.strip())
# Out:
# 3.8
# 4.0
# 3.9
# 3.8
# 3.9
# 4.0
# 4.0
# 3.8
# 3.7
# 3.7
# 3.9
# 3.9
# 3.6
# 3.9
# 4.0
# 4.1
# 4.1
# 4.0
# 4.0
# 4.1

# %%
#doing for reviews

for i in soup.find_all('span', class_= 'companyCardWrapper__ActionCount'):
    print(i.text.strip())
# Out:
# 73.8k
# 856.6k
# 6.4k
# 960
# 11.6k
# 77
# 46.8k
# 586.6k
# 4.6k
# 22.5k
# 7.1k
# 39
# 42.1k
# 561.9k
# 3.8k
# 402
# 5.8k
# 63
# 39.6k
# 429.5k
# 3.8k
# 245
# 5k
# 79
# 34.3k
# 418.2k
# 3k
# 653
# 4k
# 32
# 34.2k
# 133.8k
# 1.6k
# 254
# 3.2k
# 4
# 33.8k
# 143.6k
# 1.9k
# 57
# 3.7k
# 48
# 32.1k
# 461.7k
# 5k
# 1.1k
# 5.2k
# 85
# 28.8k
# 295.5k
# 2.6k
# 259
# 4.1k
# 35
# 27.9k
# 252.4k
# 2.5k
# 1.1k
# 3.6k
# 42
# 26.4k
# 190.9k
# 2k
# 647
# 3.7k
# 36
# 22.2k
# 98.6k
# 1.1k
# 193
# 2.2k
# 45
# 22.1k
# 84.4k
# 1.3k
# 384
# 2k
# 29
# 22k
# 106.2k
# 1.1k
# 90
# 3.3k
# 33
# 20.8k
# 66.8k
# 1.2k
# 132
# 2.6k
# 43
# 20.7k
# 122.8k
# 3.5k
# 184
# 4.2k
# 53
# 19.8k
# 220.6k
# 1.6k
# 3.1k
# 2.7k
# 20
# 19k
# 60.2k
# 1.2k
# 163
# 2k
# 101
# 18.3k
# 50.7k
# 607
# 110
# 1.5k
# 32
# 16.8k
# 79.7k
# 1.1k
# 153
# 2.9k
# 32

# %%
#now another issue when even specifying class does not help. I just want employees and HQ
for i in soup.find_all('span', class_= 'companyCardWrapper__interLinking'):
    print(i.text.strip())
# Out:
# IT Services & Consulting | 1 Lakh+ Employees | Public | 56 years old | Mumbai +342 more
# IT Services & Consulting | 1 Lakh+ Employees | Public | 35 years old | Dublin +175 more
# IT Services & Consulting | 1 Lakh+ Employees | Forbes Global 2000 | 30 years old | Teaneck. New Jersey. +159 more
# IT Services & Consulting | 1 Lakh+ Employees | Public | 79 years old | Bangalore/Bengaluru +276 more
# IT Services & Consulting | 1 Lakh+ Employees | Public | 57 years old | Paris +140 more
# Banking | 1 Lakh+ Employees | Public | 30 years old | Mumbai +1540 more
# Banking | 1 Lakh+ Employees | Public | 30 years old | Mumbai +1281 more
# IT Services & Consulting | 1 Lakh+ Employees | Public | 43 years old | Bengaluru/Bangalore +181 more
# IT Services & Consulting | 1 Lakh+ Employees | Public | 33 years old | Noida +183 more
# IT Services & Consulting | 1 Lakh+ Employees | Public | 38 years old | Pune +264 more
# ...

# %%
#better we fetch the entire container unit containing all the information 
company = soup.find_all('div', class_="companyCardWrapper")
len(company)
# Out:
# 20

# %%
name =[]

#for i in company:
    #print(i.find('h2').text.strip())
    
for i in company:
    name.append(i.find('h2').text.strip())

# %%
name
# Out:
# ['TCS',
#  'Accenture',
#  'Cognizant',
#  'Wipro',
#  'Capgemini',
#  'HDFC Bank',
#  'ICICI Bank',
#  'Infosys',
#  'HCLTech',
#  'Tech Mahindra',
#  'Genpact',
#  'Axis Bank',
#  'Teleperformance',
#  'Concentrix Corporation',
#  'Jio',
#  'Amazon',
#  'IBM',
#  'Reliance Retail',
#  'HDB Financial Services',
#  'Larsen & Toubro Limited']

# %%
rating = []
reviews= []
for i in company: 
    rating.append(i.find('span', class_= 'companyCardWrapper__companyRatingValue').text.strip())
    reviews.append(i.find('span', class_= 'companyCardWrapper__ActionCount').text.strip())

# %%
reviews
# Out:
# ['73.8k',
#  '46.8k',
#  '42.1k',
#  '39.6k',
#  '34.3k',
#  '34.2k',
#  '33.8k',
#  '32.1k',
#  '28.8k',
#  '27.9k',
#  '26.4k',
#  '22.2k',
#  '22.1k',
#  '22k',
#  '20.8k',
#  '20.7k',
#  '19.8k',
#  '19k',
#  '18.3k',
#  '16.8k']

# %%
#now for extracting the other parts which are indistinguishable on class

company[0].find('span', class_= 'companyCardWrapper__interLinking').text.strip()
# Out:
# 'IT Services & Consulting | 1 Lakh+ Employees | Public | 56 years old | Mumbai +342 more'

# %%
company_info = []
for i in company : 
    company_info.append(i.find('span', class_= 'companyCardWrapper__interLinking').text.strip())

# %%
company_info
#ask bhavin how to split
# Out:
# ['IT Services & Consulting | 1 Lakh+ Employees | Public | 56 years old | Mumbai +342 more',
#  'IT Services & Consulting | 1 Lakh+ Employees | Public | 35 years old | Dublin +175 more',
#  'IT Services & Consulting | 1 Lakh+ Employees | Forbes Global 2000 | 30 years old | Teaneck. New Jersey. +159 more',
#  'IT Services & Consulting | 1 Lakh+ Employees | Public | 79 years old | Bangalore/Bengaluru +276 more',
#  'IT Services & Consulting | 1 Lakh+ Employees | Public | 57 years old | Paris +140 more',
#  'Banking | 1 Lakh+ Employees | Public | 30 years old | Mumbai +1540 more',
#  'Banking | 1 Lakh+ Employees | Public | 30 years old | Mumbai +1281 more',
#  'IT Services & Consulting | 1 Lakh+ Employees | Public | 43 years old | Bengaluru/Bangalore +181 more',
#  'IT Services & Consulting | 1 Lakh+ Employees | Public | 33 years old | Noida +183 more',
#  'IT Services & Consulting | 1 Lakh+ Employees | Public | 38 years old | Pune +264 more',
# ...

# %%
# creating data frame from lists
d = {'Name':name, 'Rating': rating, 'Reviews': reviews, 'Company_info': company_info}

df = pd.DataFrame(d)

print(df.head())
# Out:
#         Name Rating Reviews                                       Company_info
# 0        TCS    3.8   73.8k  IT Services & Consulting | 1 Lakh+ Employees |...
# 1  Accenture    4.0   46.8k  IT Services & Consulting | 1 Lakh+ Employees |...
# 2  Cognizant    3.9   42.1k  IT Services & Consulting | 1 Lakh+ Employees |...
# 3      Wipro    3.8   39.6k  IT Services & Consulting | 1 Lakh+ Employees |...
# 4  Capgemini    3.9   34.3k  IT Services & Consulting | 1 Lakh+ Employees |...

# %%
#suppose in case we did not have a rating value for a company. in that case we would need to use 
#try: (rating.append....) except: (rating.append(np.nan))

# %%
df.dtypes
# Out:
# Name            object
# Rating          object
# Reviews         object
# Company_info    object
# dtype: object

# %%
#now running this for 10 such pages

final_df = pd.DataFrame()

for j in range(1,11):
    
    url = 'https://www.ambitionbox.com/list-of-companies?campaign=desktop_nav&page={}'.format(j)
    headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
    webpage = requests.get(url, headers = headers).text
    soup = BeautifulSoup(webpage, 'html.parser')
    company = soup.find_all('div', class_="companyCardWrapper")
    
    name =[]
    rating = []
    reviews= []
    company_info = []
    
    
    for i in company: 
        try:
            name.append(i.find('h2').text.strip())
        except:
            name.append(np.nan)
            
        try:
            rating.append(i.find('span', class_= 'companyCardWrapper__companyRatingValue').text.strip())
        except:
            rating.append(np.nan)
        
        try:
            reviews.append(i.find('span', class_= 'companyCardWrapper__ActionCount').text.strip())
        except:
            reviews.append(np.nan)
        
        try:
            company_info.append(i.find('span', class_= 'companyCardWrapper__interLinking').text.strip())
        except:
            company_info.append(np.nan)
        
    d = {'Name':name, 'Rating': rating, 'Reviews': reviews, 'Company_info': company_info}

    df = pd.DataFrame(d)
    
         
    final_df = final_df._append(df, ignore_index = True) #index restarts from 1 for each new page

# %%
final_df.sample(5)
# Out:
#                     Name Rating Reviews  \
# 156  Tata Communications    4.2      3k
# 2              Cognizant    3.9   42.1k
# 116            TVS Motor    4.1    3.7k
# 180         Tata Capital    4.2    2.8k
# 14                   Jio    4.0   20.8k
#
#                                           Company_info
# 156  Telecom | 5k-10k Employees | Public | 38 years...
# 2    IT Services & Consulting | 1 Lakh+ Employees |...
# 116  Automobile | 5k-10k Employees | Public | 45 ye...
# 180  NBFC | 5k-10k Employees | Fortune India 500 | ...
# 14   Telecom | 50k-1 Lakh Employees | Public | 17 y...
